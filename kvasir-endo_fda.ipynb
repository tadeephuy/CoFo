# %%
import torch
from TedSeg import *
from cofo import *

# %%
SEED = 512
seed_worker, g = set_seed(SEED, desterministic_algorithm=False)

# %%
from functools import partial

EXP_NAME = 'kvasir-endo_fda'
IMG_SIZE = 224
TRAIN_BS = 4*7
LR = 1e-2
N_EPOCHS = 500
ALPHA = 1.0
ALPHA_SCHEDULE = True
EMB_SIZE = 256
BETA = 0.00

OPT_FUNC = partial(torch.optim.SGD, lr=LR, momentum=0.95, nesterov=True)
LR_SCHEDULER = 'COSINE_LR'


# Loss
MODE = 'supervised'
MARGIN = 0.3
MINT_ENT_W = 0.005


METRIC = batch_dice_score

VALIDATE_EVERY = 50
TRAIN_NW = 8

def get_training_augmentation(img_size):
    train_transform = [
        albu.OneOf([
            albu.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
        ]),
        albu.HorizontalFlip(p=0.5),
        albu.VerticalFlip(p=0.5),
        albu.ShiftScaleRotate(0.05, 0.05, rotate_limit=90, border_mode=cv2.BORDER_CONSTANT, value=0, p=0.2),
        albu.SmallestMaxSize(img_size),
        albu.CenterCrop(img_size, img_size),
    ]
    return albu.Compose(train_transform)

# %%
encoder_args = {
    "pretrained":False,           
}
decoder_args = {}


MODEL = CoFoUnet(emb_size=EMB_SIZE, encoder_args=encoder_args)

# %%
import pandas as pd

train = pd.read_csv('data/csv/Kvasir_SEG/train.csv')
valid = pd.read_csv('data/csv/EndoTect_2020_Segmentation_Test_Dataset/valid.csv')
test = pd.read_csv('data/csv/EndoTect_2020_Segmentation_Test_Dataset/test.csv')

data_path = 'data/images/kvasir/'
train['image'] = data_path + 'image' + train['image']
train['mask'] = data_path + 'mask' + train['mask']

train_ds = CoFoSegmentationDataset(train, valid, get_training_augmentation, IMG_SIZE)
valid_ds = SegmentationDataset(test, get_validation_augmentation, IMG_SIZE, normalize=False)
test_ds = SegmentationDataset(test, get_validation_augmentation, IMG_SIZE, normalize=False)

# %%
valid_ds.show_img()

# %%
train_ds.show_img()

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=TRAIN_BS, 
                      shuffle=True, num_workers=TRAIN_NW, pin_memory=True,
                        worker_init_fn=seed_worker,
                        generator=g, drop_last=True)
valid_dl = DataLoader(valid_ds, batch_size=16, 
                      num_workers=4, shuffle=False,
                     worker_init_fn=seed_worker,
                        generator=g, )

# %%
learn = CoFoLearner(model=MODEL, data=(train_dl, valid_dl),
                    loss=dice_loss, 
                    name=EXP_NAME, metric=METRIC)

# %%
import torch
n_epochs = N_EPOCHS
optim = OPT_FUNC(learn.model.parameters())

COSINE_LR = partial(torch.optim.lr_scheduler.CosineAnnealingLR, T_max=len(learn.data[0])*N_EPOCHS)
lr_scheduler = eval(LR_SCHEDULER)(optim)

# %%
cofo_loss = cofo_loss(mode=MODE, mint_ent_w=MINT_ENT_W, margin=MARGIN)

# %%
learn.fit(n_epochs, optim, lr_scheduler,
          cofo_loss=cofo_loss,
          beta=0.01,
          contrastive=False,
          alpha=0.0, alpha_content=0.0,
          schedule_alpha=True,
          scheduler_mode='iteration', validate_every=10)#VALIDATE_EVERY)
# Out:
# /home/me/.local/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# <PIL.Image.Image image mode=RGB size=896x448 at 0x7FB4E63C0940>
# Ep.    0|train_dice_loss: 0.656|valid_loss: 0.682|valid_metric: 0.369 -saved
# Ep.   10|train_dice_loss: 0.319|valid_loss: 0.503|valid_metric: 0.443 -saved
# Ep.   20|train_dice_loss: 0.209|valid_loss: 0.294|valid_metric: 0.640 -saved
# Ep.   30|train_dice_loss: 0.163|valid_loss: 0.240|valid_metric: 0.714 -saved
# Ep.   40|train_dice_loss: 0.122|valid_loss: 0.215|valid_metric: 0.758 -saved
# Ep.   50|train_dice_loss: 0.101|valid_loss: 0.227|valid_metric: 0.757
# Ep.   60|train_dice_loss: 0.088|valid_loss: 0.173|valid_metric: 0.824 -saved
# Ep.   70|train_dice_loss: 0.083|valid_loss: 0.176|valid_metric: 0.819
# Ep.   80|train_dice_loss: 0.083|valid_loss: 0.189|valid_metric: 0.792
# Ep.   90|train_dice_loss: 0.074|valid_loss: 0.194|valid_metric: 0.789
# Ep.  100|train_dice_loss: 0.069|valid_loss: 0.168|valid_metric: 0.827 -saved
# Ep.  110|train_dice_loss: 0.066|valid_loss: 0.174|valid_metric: 0.825
# Ep.  120|train_dice_loss: 0.063|valid_loss: 0.195|valid_metric: 0.787
# Ep.  130|train_dice_loss: 0.064|valid_loss: 0.224|valid_metric: 0.765
# Ep.  140|train_dice_loss: 0.057|valid_loss: 0.180|valid_metric: 0.812
# Ep.  150|train_dice_loss: 0.055|valid_loss: 0.176|valid_metric: 0.824
# Ep.  160|train_dice_loss: 0.053|valid_loss: 0.152|valid_metric: 0.846 -saved
# Ep.  170|train_dice_loss: 0.046|valid_loss: 0.167|valid_metric: 0.833
# Ep.  180|train_dice_loss: 0.051|valid_loss: 0.168|valid_metric: 0.836
# Ep.  190|train_dice_loss: 0.047|valid_loss: 0.161|valid_metric: 0.835
# Ep.  200|train_dice_loss: 0.041|valid_loss: 0.152|valid_metric: 0.849
# Ep.  210|train_dice_loss: 0.041|valid_loss: 0.154|valid_metric: 0.846
# Ep.  220|train_dice_loss: 0.041|valid_loss: 0.151|valid_metric: 0.843 -saved
# Ep.  230|train_dice_loss: 0.040|valid_loss: 0.158|valid_metric: 0.844
# Ep.  240|train_dice_loss: 0.039|valid_loss: 0.150|valid_metric: 0.851 -saved
# Ep.  250|train_dice_loss: 0.035|valid_loss: 0.166|valid_metric: 0.839
# Ep.  260|train_dice_loss: 0.038|valid_loss: 0.156|valid_metric: 0.851
# Ep.  270|train_dice_loss: 0.040|valid_loss: 0.156|valid_metric: 0.851
# Ep.  280|train_dice_loss: 0.044|valid_loss: 0.159|valid_metric: 0.849
# Ep.  290|train_dice_loss: 0.036|valid_loss: 0.152|valid_metric: 0.849
# Ep.  300|train_dice_loss: 0.034|valid_loss: 0.148|valid_metric: 0.861 -saved
# Ep.  310|train_dice_loss: 0.033|valid_loss: 0.147|valid_metric: 0.857 -saved
# Ep.  320|train_dice_loss: 0.035|valid_loss: 0.144|valid_metric: 0.854 -saved
# Ep.  330|train_dice_loss: 0.031|valid_loss: 0.150|valid_metric: 0.860
# Ep.  340|train_dice_loss: 0.032|valid_loss: 0.149|valid_metric: 0.856
# Ep.  350|train_dice_loss: 0.030|valid_loss: 0.139|valid_metric: 0.868 -saved
# Ep.  360|train_dice_loss: 0.034|valid_loss: 0.145|valid_metric: 0.863
# Ep.  370|train_dice_loss: 0.032|valid_loss: 0.142|valid_metric: 0.867
# Ep.  380|train_dice_loss: 0.031|valid_loss: 0.140|valid_metric: 0.867
# Ep.  390|train_dice_loss: 0.031|valid_loss: 0.143|valid_metric: 0.865
# Ep.  400|train_dice_loss: 0.031|valid_loss: 0.144|valid_metric: 0.864
# Ep.  410|train_dice_loss: 0.028|valid_loss: 0.141|valid_metric: 0.867
# Ep.  420|train_dice_loss: 0.028|valid_loss: 0.142|valid_metric: 0.867
# Ep.  430|train_dice_loss: 0.031|valid_loss: 0.141|valid_metric: 0.867
# Ep.  440|train_dice_loss: 0.028|valid_loss: 0.140|valid_metric: 0.868
# Ep.  450|train_dice_loss: 0.027|valid_loss: 0.143|valid_metric: 0.866
# Ep.  460|train_dice_loss: 0.029|valid_loss: 0.141|valid_metric: 0.867
# Ep.  470|train_dice_loss: 0.029|valid_loss: 0.142|valid_metric: 0.866
# Ep.  480|train_dice_loss: 0.028|valid_loss: 0.141|valid_metric: 0.866
# Ep.  490|train_dice_loss: 0.031|valid_loss: 0.141|valid_metric: 0.867

# %%
test = pd.read_csv('data/csv/CVC-EndoSceneStill/test.csv')
test_ds = SegmentationDataset(test, get_validation_augmentation, IMG_SIZE, normalize=False)
test_loader = DataLoader(test_ds, 4, num_workers=4)


learn.get_dice_score(test_loader)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:01<00:00 0.75]
#     </div>
# 0.75162345
